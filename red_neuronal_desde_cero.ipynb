# %% [markdown]
# ATAJOS:
# - correr una celda: ctrl + Enter
# - correr una celda y pasar a la siguiente: shift + Enter
# - crear una nueva celda: alt + Enter

# %%
import numpy as np
import scipy as sc
import matplotlib.pyplot as plt

from sklearn.datasets import make_circles

# %%
# Crear el dataset
make_circles?

n = 500  # Número de registros
p = 2    # carácterísticas

X, Y = make_circles(n_samples=n, factor=.5, noise=.05)

plt.scatter(X[Y==0,0], X[Y==0,1], c="blue")
plt.scatter(X[Y==1,0], X[Y==1,1], c='red')
plt.axis('equal')
plt.show()

# %%
# CLASE DE LA CAPA DE LA RED

class neural_leyer():

  def __init__(self, n_conn, n_neur, act_f):
    
    self.act_f = act_f
    
    self.bias = np.random.rand(1, n_neur)      * 2 - 1 
    self.W    = np.random.rand(n_conn, n_neur) * 2 - 1

# %%
# FUNCIÓN DE ACTIVACIÓN SIGMOIDE

sigm = (lambda x: 1 / (1+ np.e ** (-x) ),  # función sigmoide
        lambda x: x * (1 - x))             # derivada de la función sigmoide

# ejemplo
_x = np.linspace(-5, 5, 100)
fig, (ax1, ax2) = plt.subplots(1, 2) 
ax1.plot(_x, sigm[0](_x)) 
ax2.plot(_x, sigm[1](_x)) 
plt.show()

# %%
# FUNCIÓN DE ACTIVACIÓN RELU

relu = lambda x: np.maximum(0, x)

plt.plot(_x, relu(_x))
plt.show()

# %%
# RED NEURONAL


layer0
